# %%
import pandas as pd

# %%
df = pd.read_csv('foodb_2020_04_07_csv/Content.csv')
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (4,5,6,7,8,9,13,14,21,22,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.columns
# Out:
# Index(['id', 'source_id', 'source_type', 'food_id', 'orig_food_id',
#        'orig_food_common_name', 'orig_food_scientific_name', 'orig_food_part',
#        'orig_source_id', 'orig_source_name', 'orig_content', 'orig_min',
#        'orig_max', 'orig_unit', 'orig_citation', 'citation', 'citation_type',
#        'creator_id', 'updater_id', 'created_at', 'updated_at', 'orig_method',
#        'orig_unit_expression', 'standard_content', 'preparation_type',
#        'export'],
#       dtype='object')

# %%
df.iloc[:, 20:30].head(20)
# Out:
#                  updated_at orig_method orig_unit_expression  \
# 0   2019-12-11 20:23:57 UTC         NaN                  NaN
# 1   2019-12-11 20:23:57 UTC         NaN                  NaN
# 2   2019-12-11 20:23:57 UTC         NaN                  NaN
# 3   2019-12-11 20:23:57 UTC         NaN                  NaN
# 4   2019-12-11 20:23:57 UTC         NaN                  NaN
# 5   2019-12-11 20:23:57 UTC         NaN                  NaN
# 6   2019-12-11 20:23:57 UTC         NaN                  NaN
# 7   2019-12-11 20:23:57 UTC         NaN                  NaN
# 8   2019-12-11 20:23:57 UTC         NaN                  NaN
# 9   2019-12-11 20:23:57 UTC         NaN                  NaN
# 10  2019-12-11 20:23:57 UTC         NaN                  NaN
# 11  2019-12-11 20:23:57 UTC         NaN                  NaN
# 12  2019-12-11 20:23:57 UTC         NaN                  NaN
# 13  2019-12-11 20:23:57 UTC         NaN                  NaN
# ...

# %%
df[df['preparation_type']=='beverage (Alcoholic)']
# Out:
#               id  source_id source_type  food_id orig_food_id  \
# 2487        2488          2    Nutrient      268          346
# 2488        2489          2    Nutrient      268          346
# 2489        2490          2    Nutrient      268          979
# 2490        2491          2    Nutrient      268          979
# 2491        2492          2    Nutrient      268          347
# ...          ...        ...         ...      ...          ...
# 1741227  1802252         39    Nutrient      279        14037
# 1741228  1802253         39    Nutrient      279        14037
# 1741321  1802346         39    Nutrient      640        14052
# 1741326  1802351         39    Nutrient      279        14037
# 1741336  1802361         39    Nutrient      763        43479
#
#                                      orig_food_common_name  \
# 2487                   Beer, danish household, low alcohol
# 2488                   Beer, danish household, low alcohol
# ...

# %%
df[df['orig_food_part'] != 'NaN']["orig_food_part"].head(100)
# Out:
# 0     Fruit
# 1      Bulb
# 2      Leaf
# 3      Leaf
# 4     Fruit
#       ...
# 95     Seed
# 96     Seed
# 97    Fruit
# 98     Leaf
# 99     Seed
# Name: orig_food_part, Length: 100, dtype: object

# %%
v_counts = df['orig_food_common_name'].value_counts()

# %%
len(v_counts[v_counts > 40])
# Out:
# 7464

# %%
len(v_counts)
# Out:
# 9460

# %%
foods = df.groupby(by='orig_food_common_name', as_index = True).count()

# %%
foods
# Out:
#                               id  source_id  source_type  food_id  \
# orig_food_common_name
# (Capsicum anuum)               1          1            1        1
# (Cucumis melo)                 1          1            1        1
# (Ipomoea batatas)              1          1            1        1
# (Lactuca sativa var. crispa)   1          1            1        1
# (Medicago sativa)              1          1            1        1
# ...                           ..        ...          ...      ...
# steam-distilled onion oil     22         22           22       22
# taco shell                    41         41           41       41
# tortilla flour                30         30           30       30
# unsure                         2          2            2        2
# whole leaves of lettuce       59         59           59       59
#
#                               orig_food_id  orig_food_scientific_name  \
# orig_food_common_name
# ...

# %% [markdown]
#  ``{'split','records','index',
#         'columns','values', 'table'}``

# %%
import requests
from pandas.io.json import json_normalize
import pandas as pd
url='https://www.thecocktaildb.com/api/json/v1/1/lookup.php?i=178341'

#url='https://www.thecocktaildb.com/api/json/v1/1/filter.php?i=Gin'
#url = "https://www.thecocktaildb.com/api/json/v1/1/filter.php?a=Alcoholic"
drinks_data = pd.read_json(url)
drink_list = list(drinks_data["drinks"])
#print(drink_list)

ingredient_columns = ['strIngredient' + str(num) for num in range(1,16)]
#strIngredient1	strIngredient2	strIngredient3	strIngredient4	strIngredient5	strIngredient6	strIngredient7	strIngredient8	strIngredient9
drink_df = pd.DataFrame(drink_list)
drink_df[ingredient_columns]
# Out:
#   strIngredient1 strIngredient2 strIngredient3  strIngredient4 strIngredient5  \
# 0            Gin   Orange Juice    Lemon Juice  Rosemary Syrup     Soda Water
#
#   strIngredient6 strIngredient7 strIngredient8 strIngredient9 strIngredient10  \
# 0       Rosemary    Orange Peel           None           None            None
#
#   strIngredient11 strIngredient12 strIngredient13 strIngredient14  \
# 0            None            None            None            None
#
#   strIngredient15
# 0            None

# %%
drink_list = []
for row in json_df.iterrows():
    #print(row)
    #print(type(row))
    n, dic = row
    drink_list.append(dic)

#drink_list[0]
n
# Out:
# 99

# %%
import requests
import json
import webbrowser

c_df = pd.DataFrame()

def cocktails():
    f = r"https://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail"
    data = requests.get(f)
    tt = json.loads(data.text)
    #webbrowser.open(tt["url"])
    c_df = pd.DataFrame(tt)
    for i in (tt["drinks"]):
        pass
        #print(i, "\n")
    #print(len(tt["drinks"]))    
cocktails()

c_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  

url = "https://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail"

with open(url) as f: 
    d = json.load(f) 

 

# lets put the data into a pandas df 
# clicking on raw_nyc_phil.json under "Input Files" 
# tells us parent node is 'programs' 
df_cocktails = json_normalize(d['cocktails']) 
df_cocktails.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-111-7b72f0f1763f> in <module>
#       5 url = "https://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail"
#       6
# ----> 7 with open(url) as f:
#       8     d = json.load(f)
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://www.thecocktaildb.com/api/json/v1/1/filter.php?c=Cocktail'

# %%
import requests
import json
import webbrowser
def cocktails():
    f = r"https://www.thecocktaildb.com/api/json/v1/1/filter.php?i=Gin"
    data = requests.get(f)
    tt = json.loads(data.text)
    print(tt)
    
    for i in (tt["drinks"]):
        try:
            url = i["strDrinkThumb"]
            #webbrowser.open(url)
            print(i, "\n")
            print(i["strDrink"], "\n")
        except Exception:
            pass
cocktails()
# Out:
# {'drinks': [{'strDrink': '3-Mile Long Island Iced Tea', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/rrtssw1472668972.jpg', 'idDrink': '15300'}, {'strDrink': '69 Special', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/vqyxqx1472669095.jpg', 'idDrink': '13940'}, {'strDrink': 'A1', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/2x8thr1504816928.jpg', 'idDrink': '17222'}, {'strDrink': 'Abbey Cocktail', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/mr30ob1582479875.jpg', 'idDrink': '17834'}, {'strDrink': 'Abbey Martini', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/2mcozt1504817403.jpg', 'idDrink': '17223'}, {'strDrink': 'Ace', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/l3cd7f1504818306.jpg', 'idDrink': '17225'}, {'strDrink': 'Adam & Eve', 'strDrinkThumb': 'https://www.thecocktaildb.com/images/media/drink/vfeumw1504819077.jpg', 'idDrink': '17226'}, {'strDrink'
# ...
